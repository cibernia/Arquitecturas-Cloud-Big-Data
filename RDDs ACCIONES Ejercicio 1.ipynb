# %% [markdown]
# ### RDDs ACCIONES
# rdd= rdd1.flatMap(...).filter(...)
# print(rdd.count())
#
# DIAPOSITIVAS
# https://docs.google.com/presentation/d/1UU5Rdy3N3v0msdpE4gB8iju25vENvHNE/edit?usp=share_link&ouid=108221443273434880064&rtpof=true&sd=true
#
# quijote.txt
# https://drive.google.com/file/d/1h1luILF_cuXS9U9a91w-PaoIjnPIBj6B/view?usp=share_link

# %%
# subir achivo quijote.txt en menú Archivo->Upload datos en el DBFS... y copiar la ruta del archivo
# mi resultado: dbfs:/FileStore/shared_uploads/ciberniainfo@gmail.com/quijote-1.txt

file = 'dbfs:/FileStore/shared_uploads/ciberniainfo@gmail.com/quijote-1.txt' # ojo poner entre comillas '  '

lineas = sc.textFile(file)
print ('numero de lineas -> ', lineas.count()) # no utilizar collect porq el tamaño del archivo ya es grande
print('primeras cinco lineas ->' ,lineas.take(5)) # entrega las primeras 5 lineas en formato de lista, muestra también las lineneas en blanco como ''
# Out:
# numero de lineas ->  36881
# primeras cinco lineas -> ['Capítulo primero. Que trata de la condición y ejercicio del famoso hidalgo', 'don Quijote de la Mancha', '', '', 'En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho']

# %%
palabras_linea = lineas.map(lambda elemento: elemento.split()) #separa en listas cada frase
palabras_linea.take(5)
# Out:
# Out[14]: [['Capítulo',
#   'primero.',
#   'Que',
#   'trata',
#   'de',
#   'la',
#   'condición',
#   'y',
#   'ejercicio',
#   'del',
#   'famoso',
#   'hidalgo'],
#  ['don', 'Quijote', 'de', 'la', 'Mancha'],
#  [],
#  [],
#  ['En',
#   'un',
#   'lugar',
#   'de',
#   'la',
#   'Mancha,',
#   'de',
#   'cuyo',
#   'nombre',
#   'no',
#   'quiero',
#   'acordarme,',
#   'no',
#   'ha',
#   'mucho']]

# %%
num_palabras_linea = palabras_linea.map(lambda elemento: len(elemento))
num_palabras_linea.take(10)# numero de palabras en las 10 primeras lineas
# Out:
# Out[15]: [12, 5, 0, 0, 15, 13, 13, 11, 10, 13]

# %%
num_palabras_linea.reduce(lambda elemento1, elemento2: elemento1+elemento2)
# Out:
# Out[10]: 376500

# %%
palabras_linea2 = lineas.flatMap(lambda elemento: elemento.split()) # ..split separa cada alabras, faltMap no hace listas como .map []

palabras_linea2.take(15)
# Out:
# Out[11]: ['Capítulo',
#  'primero.',
#  'Que',
#  'trata',
#  'de',
#  'la',
#  'condición',
#  'y',
#  'ejercicio',
#  'del',
#  'famoso',
#  'hidalgo',
#  'don',
#  'Quijote',
#  'de']

# %%
palabras_linea2.count()
# Out:
# Out[12]: 376500
